# %%
import cv2
import os
import numpy as np
import matplotlib.pyplot as plt
from skimage.transform import resize
from skimage.io import imread

# %%
imgs_mask_pred = os.listdir('preds')

# %%
imgs_mask_pred2 = np.ndarray((2323,192,192), dtype = np.uint8)

# %%
imgs_id = np.load('imgs_id_train.npy')
# imgs = np.load('imgs_train.npy')
# imgs_mask_gt = np.load('imgs_mask_train.npy')
# imgs_mask_pred = np.load('imgs_mask_pred.npy')

# %%
imgs_id.shape
# Out:
# (2323,)

# %%
i = 0
for img_id in imgs_id:
    image_name = str(img_id) + '_pred.png'
    imgs_mask_pred2[i] = imread(os.path.join('preds/',image_name), as_grey=True)
    if i % 100 == 0:
        print('Done: {0}/{1} images'.format(i, imgs_id.shape[0]))
    i += 1
# Out:
# Done: 0/2323 images
# Done: 100/2323 images
# Done: 200/2323 images
# Done: 300/2323 images
# Done: 400/2323 images
# Done: 500/2323 images
# Done: 600/2323 images
# Done: 700/2323 images
# Done: 800/2323 images
# Done: 900/2323 images
# Done: 1000/2323 images
# Done: 1100/2323 images
# Done: 1200/2323 images
# Done: 1300/2323 images
# Done: 1400/2323 images
# Done: 1500/2323 images
# Done: 1600/2323 images
# Done: 1700/2323 images
# Done: 1800/2323 images
# Done: 1900/2323 images
# Done: 2000/2323 images
# Done: 2100/2323 images
# Done: 2200/2323 images
# Done: 2300/2323 images

# %%
plt.imshow(imgs_mask_pred2[0],cmap='gray')
plt.show()

# %%
imgs_q = np.ndarray((2323,420,580), dtype = np.uint8)

# %%
i = 0
for img_id in imgs_id:
    image_name = str(img_id) + '_pred.png'
    imgs_mask_pred2[i] = imread(os.path.join('preds/',image_name), as_grey=True)
    if i % 100 == 0:
        print('Done: {0}/{1} images'.format(i, imgs_id.shape[0]))
    i += 1

# %%
print(imgs_id.shape)
print(imgs.shape)
print(imgs_mask_gt.shape)
print(imgs_mask_pred.shape)
# Out:
# (2323,)
# (2323, 420, 580)
# (2323, 420, 580)
# (2323, 192, 192, 1)

# %%
plt.imshow(imgs[0],cmap='gray')
plt.show()

# %%
del imgs
del imgs_mask_gt
# del imgs_mask_pred

# %%
imgs_p = np.ndarray((2323,192,192), dtype = np.uint8)

# %%
i = 0
for img in imgs_mask_pred:
    img = np.reshape(img,(192,192))
#     print(img.shape)
    imgs_p[i] = img
    i+=1

# %%
imgs_q = np.ndarray((2323,420,580), dtype = np.uint8)

# %%
i = 0
for img in imgs_p:
    imgs_q[i] = resize(img, (420, 580), preserve_range=True)
    i+=1
# Out:
# d:\ProgramData\Anaconda3\envs\sbenv\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "

# %%
plt.imshow(imgs_p[0],cmap='gray')
plt.show()

# %%
plt.imshow(imgs_q[0],cmap='gray')
plt.show()

# %%
plt.imshow(imgs_mask_pred[4],cmap='gray')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-40-1be3f562d139> in <module>()
# ----> 1 plt.imshow(imgs_mask_pred[4],cmap='gray')
#       2 plt.show()
#
# d:\ProgramData\Anaconda3\envs\sbenv\lib\site-packages\matplotlib\pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, hold, data, **kwargs)
#    3078                         filternorm=filternorm, filterrad=filterrad,
#    3079                         imlim=imlim, resample=resample, url=url, data=data,
# -> 3080                         **kwargs)
#    3081     finally:
#    3082         ax._hold = washold
#
# d:\ProgramData\Anaconda3\envs\sbenv\lib\site-packages\matplotlib\__init__.py in inner(ax, *args, **kwargs)
#    1708                     warnings.warn(msg % (label_namer, func.__name__),
# ...

# %%
print(imgs_id[0])
# Out:
# 30_87

# %%
img = imread('preds/30_87_pred.png', as_grey=True)
img = resize(img, (420,580), preserve_range=True)
# Out:
# d:\ProgramData\Anaconda3\envs\sbenv\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "

# %%
plt.imshow(img,cmap='gray')
plt.show()
